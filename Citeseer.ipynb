# %% [markdown]
# # Name: Indra Sai Kiran Valluru
# # CiteSeer Data Set Collection Processing (CS582: Information Retrieval)

# %%
# Import necessary modules
import os
import pandas as pd
import re
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
import collections

# %%
# Import gensim library to deal with stopwords
import gensim
from gensim.parsing.preprocessing import remove_stopwords, STOPWORDS
print(STOPWORDS)
# Out:
# frozenset({'perhaps', 'be', 'nevertheless', 'once', 'mill', 'would', 'per', 'thence', 'mostly', 'ie', 'than', 'been', 'whole', 'herself', 'two', 'whatever', 'nowhere', 'also', 'can', 'hers', 'fire', 'latterly', 'before', 'side', 'noone', 'fill', 'because', 'eight', 'ltd', 'amongst', 'twelve', 'it', 'should', 'herein', 'please', 'beside', 'he', 'another', 'below', 'formerly', 'is', 'behind', 'too', 'being', 'now', 'whom', 'therein', 'serious', 'de', 'with', 'why', 'anything', 'did', 'this', 'whose', 'everywhere', 'me', 'due', 'such', 'something', 'on', 'between', 'very', 'never', 'along', 'used', 'move', 'anyway', 'other', 'same', 'but', 'using', 'around', 'cry', 're', 'sincere', 'beyond', 'himself', 'onto', 'are', 'throughout', 'twenty', 'how', 'made', 'these', 'nobody', 'during', 'wherever', 'up', 'empty', 'since', 'upon', 'whereas', 'them', 'put', 'until', 'had', 'several', 'amoungst', 'un', 'eleven', 'enough', 'somewhere', 'the', 'bottom', 'if', 'some', 'by', 'thus', 'last', 'they', 'afterwards', 'whether', 'one', 'anyone', 'or', 'whereafter', 'across', 'various', 'for', 'sometime', 'otherwise', 'somehow', 'give', 'say', 'more', 'describe', 'ourselves', 'co', 'hereby', 'fifteen', 'nine', 'elsewhere', 'often', 'doesn', 'many', 'just', 'whenever', 'top', 'and', 'kg', 'his', 'already', 'both', 'themselves', 'front', 'their', 'didn', 'sometimes', 'nothing', 'into', 'hundred', 'besides', 'does', 'though', 'must', 'system', 'amount', 'yet', 'see', 'among', 'i', 'con', 'became', 'alone', 'found', 'either', 'after', 'always', 'all', 'wherein', 'am', 'hereupon', 'regarding', 'rather', 'then', 'thru', 'mine', 'neither', 'do', 'beforehand', 'seemed', 'our', 'meanwhile', 'ours', 'few', 'ever', 'each', 'thin', 'someone', 'from', 'against', 'towards', 'in', 'five', 'we', 'any', 'full', 'go', 'yours', 'former', 'six', 'call', 'about', 'unless', 'will', 'through', 'might', 'still', 'latter', 'when', 'seem', 'him', 'of', 'ten', 'within', 'couldnt', 'make', 'thereafter', 'off', 'least', 'become', 'detail', 'take', 'myself', 'part', 'even', 'much', 'here', 'to', 'not', 'cant', 'find', 'down', 'hasnt', 'becomes', 'out', 'thick', 'a', 'interest', 'no', 'next', 'quite', 'were', 'done', 'seeming', 'show', 'could', 'what', 'namely', 'was', 'over', 'every', 'seems', 'third', 'anyhow', 'none', 'itself', 'else', 'toward', 'as', 'have', 'she', 'although', 'less', 'your', 'may', 'whereupon', 'under', 'its', 'first', 'you', 'thereby', 'except', 'hence', 'those', 'an', 'becoming', 'etc', 'everyone', 'four', 'others', 'her', 'only', 'eg', 'forty', 'which', 'keep', 'whereby', 'yourselves', 'without', 'get', 'whence', 'bill', 'sixty', 'name', 'really', 'back', 'who', 'however', 'own', 'therefore', 'everything', 'three', 'nor', 'most', 'so', 'us', 'thereupon', 'where', 'yourself', 'whither', 'hereafter', 'anywhere', 'well', 'together', 'has', 'at', 'indeed', 'via', 'cannot', 'almost', 'further', 'while', 'above', 'moreover', 'there', 'fifty', 'again', 'computer', 'that', 'don', 'km', 'doing', 'whoever', 'my', 'inc'})

# %%
# File-path
path = 'citeseer'
filenames = os.listdir(path)

# %%
# Parsing and merging all files into merge.txt
with open('merge.txt', 'w') as outfile:
    for fname in filenames:
        filepath = 'citeseer/'+fname
        with open(filepath) as infile:
            outfile.write(infile.read())
        infile.close()
outfile.close()

# %% [markdown]
# ## Task 1: Tokenize on whitespace and remove punctuation.

# %%
# Tokenize on whitespace and remove punctuation.
infile = open('merge.txt','r')
text = infile.read()
lines = text.lower() 

# Eliminate punctuation using regex
lines = re.sub(r'[^\w\s]+','',lines)     
tokens = lines.split()

# Writing tokens to a file
with open('tokens_1.txt','w') as outfile:            
    for listitem in tokens:
        outfile.write("%s " % listitem)

# %% [markdown]
# ## Task 2:

# %%
# Frequency of words in the collection
count = {}
for word in open('tokens_1.txt').read().split(' '):
    if word in count:
        count[word] += 1
    else:
        count[word] = 1
        
print(count)
# Out:
# {'positioning': 6, 'a': 13345, 'coarsecalibrated': 1, 'camera': 55, 'with': 3200, 'respect': 104, 'to': 11536, 'an': 3281, 'unknown': 35, 'object': 369, 'by': 2765, '2d': 47, '12': 48, 'visual': 279, 'servoing': 13, 'in': 10067, 'this': 4446, 'paper': 2208, 'we': 5138, 'propose': 382, 'new': 976, 'visionbased': 37, 'robot': 305, 'control': 445, 'approach': 1167, 'halfway': 1, 'between': 639, 'the': 25662, 'classical': 88, 'positionbased': 2, 'and': 14131, 'imagebased': 2, 'servoings': 1, 'it': 1541, 'allows': 308, 'avoid': 46, 'their': 920, 'respective': 14, 'disadvantages': 13, 'homography': 1, 'some': 608, 'planar': 8, 'feature': 268, 'points': 97, 'extracted': 58, 'from': 1909, 'two': 704, 'images': 207, 'corresponding': 65, 'current': 340, 'desired': 44, 'poses': 22, 'is': 6577, 'computed': 36, 'at': 858, 'each': 587, 'iteration': 10, 'then': 429, 'approximate': 78, 'partialpose': 1, 'where': 383, 'translational': 3, 'term': 78, 'known': 127, 'only': 422, 'up': 162, 'scale': 76, 'factor': 31, 'deduced': 1, 'which': 1916, 'can': 2057, 'be': 2500, 'designed': 194, 'closedloop': 6, 'law': 23, 'controlling': 25, 'six': 21, 'dof': 3, 'contrarily': 2, 'our': 1333, 'scheme': 165, 'does': 126, 'not': 869, 'need': 308, 'any': 307, 'geometric': 31, '3d': 158, 'model': 1209, 'of': 18638, 'furthermore': 103, 'ensures': 11, 'convergence': 39, 'all': 449, 'task': 449, 'space': 390, 'how': 731, 'building': 219, 'datablades': 2, 'that': 4820, 'know': 53, 'value': 117, 'everything': 6, 'cost': 180, 'nothing': 6, 'objectrelational': 43, 'database': 835, 'management': 403, 'system': 1897, 'ordbms': 7, 'offers': 56, 'many': 624, 'potential': 129, 'benefits': 54, 'for': 7379, 'scientific': 68, 'multimedia': 129, 'financial': 18, 'applications': 879, 'however': 462, 'work': 628, 'remains': 32, 'integration': 268, 'domainspecific': 32, 'class': 254, 'libraries': 132, 'data': 2691, 'cartridges': 2, 'extenders': 1, 'into': 689, 'query': 1131, 'processing': 400, 'major': 130, 'problem': 993, 'standard': 197, 'mechanisms': 129, 'selectivity': 17, 'estimation': 88, 'taken': 61, 'relational': 214, 'systems': 1840, 'rely': 38, 'on': 3656, 'properties': 207, 'specific': 217, 'types': 209, 'creation': 75, 'extremely': 36, 'difficult': 162, 'because': 216, 'software': 565, 'interfaces': 242, 'provided': 149, 'vendors': 7, 'are': 3737, 'relatively': 62, 'lowlevel': 29, 'discuss': 248, 'extensions': 64, 'generalized': 46, 'search': 988, 'tree': 108, 'or': 1317, 'gist': 2, 'support': 574, 'higherlevel': 9, 'but': 529, 'less': 81, 'typespecific': 1, 'specifically': 77, 'computation': 102, 'estimates': 39, 'confidence': 30, 'intervals': 28, 'using': 1305, 'variety': 165, 'indexbased': 1, 'approaches': 370, 'present': 782, 'results': 926, 'experimental': 225, 'comparison': 71, 'these': 1267, 'methods': 684, 'several': 486, 'estimators': 9, 'literature': 98, '1': 1552, 'intro': 2, 'impulse': 3, 'locationbased': 2, 'agent': 1057, 'assistance': 26, 'physical': 171, 'world': 399, 'user': 1040, 'experiences': 55, 'products': 45, 'places': 32, 'explores': 26, 'surroundings': 6, 'participates': 1, 'locationspecific': 1, 'activities': 105, 'agents': 1627, 'trapped': 2, 'electronic': 161, 'offer': 66, 'users': 716, 'valuable': 34, 'online': 204, 'example': 287, 'personalizing': 1, 'searches': 38, 'queries': 648, 'research': 690, 'project': 196, 'mit': 5, 'media': 59, 'lab': 21, 'examines': 27, 'what': 227, 'happens': 5, 'when': 553, 'rich': 60, 'experience': 119, 'augmented': 156, 'low': 72, 'costs': 37, 'information': 2322, 'resources': 193, 'available': 304, 'through': 372, 'internet': 316, 'presents': 308, 'subset': 63, 'implementation': 346, 'one': 765, 'aspect': 46, 'vision': 133, 'scenario': 44, 'demonstrating': 17, 'mobile': 695, 'device': 84, 'uses': 223, 'locationaware': 10, 'digitally': 3, 'augment': 17, 'explore': 93, 'overview': 101, 'related': 202, 'learning': 1431, 'within': 296, 'wireless': 69, 'devices': 161, '6': 84, 'combined': 107, 'wearable': 187, 'c ...

# %%
# Total number of words in the collection
file = open('tokens_1.txt')
read_data = file.read()
words = read_data.split()
len(words)
# Out:
# 476203

# %%
# Total number of unique words in the collection
len(count)
# Out:
# 19890

# %%
# Top 20 words and their frequencies in the collection
import operator
from itertools import islice

top20_words = dict(sorted(count.items(), key=operator.itemgetter(1),reverse=True)[:20])
print(top20_words)
# Out:
# {'the': 25662, 'of': 18638, 'and': 14131, 'a': 13345, 'to': 11536, 'in': 10067, 'for': 7379, 'is': 6577, 'we': 5138, 'that': 4820, 'this': 4446, 'are': 3737, 'on': 3656, 'an': 3281, 'with': 3200, 'as': 3057, 'by': 2765, 'data': 2691, 'be': 2500, 'information': 2322}

# %%
# Stopwords in the Top 20 words in the collection
for i in top20_words.keys():
    if i in STOPWORDS:
        print(i)
# Out:
# the
# of
# and
# a
# to
# in
# for
# is
# we
# that
# this
# are
# on
# an
# with
# as
# by
# be

# %%
# Minimum number of unique words accounting for 15% of the total number of words in the collection
c=0
no_of_words=0
count = dict(sorted(count.items(), key=operator.itemgetter(1),reverse=True))
limit = len(words)*0.15
for i in count:
    if c < limit and count[i] <= (limit - c):
        print(i,':', count[i])
        c += count[i]
        no_of_words += 1   
print('Number of words:',no_of_words)
print('Total count:',c)
# Out:
# the : 25662
# of : 18638
# and : 14131
# to : 11536
# web : 1432
# factor : 31
# Number of words: 6
# Total count: 71430

# %% [markdown]
# ## Task 3:

# %%
# Tokenize on whitespace and remove punctuation.
infile = open('merge.txt','r')
text = infile.read()
lines = text.lower() 
lines = re.sub(r'[^\w\s]+',' ',lines)

# Remove stopwords
t=remove_stopwords(lines)
clean_tokens = [word for word in t if word.lower() not in STOPWORDS]

# Initiallizing Porter Stemmer object
st = PorterStemmer()

# Stemming the words
stem_tokens = [st.stem(word) for word in clean_tokens]

# Writing tokens to a file
with open('tokens_3.txt','w') as outfile:                                  
    for listitem in t:
        outfile.write("%s" % listitem)

# %%
# Frequency of words in the collection
count = {}
for word in open('tokens_3.txt').read().split():
    if word in count:
        count[word] += 1
    else:
        count[word] = 1

print(count)
# Out:
# {'positioning': 7, 'coarse': 11, 'calibrated': 2, 'camera': 59, 'respect': 104, 'unknown': 37, 'object': 646, '2d': 37, '1': 1783, '2': 485, 'visual': 291, 'servoing': 13, 'paper': 2211, 'propose': 382, 'new': 977, 'vision': 173, 'based': 2534, 'robot': 370, 'control': 453, 'approach': 1169, 'halfway': 1, 'classical': 91, 'positionbased': 1, 'image': 325, 'servoings': 1, 'allows': 308, 'avoid': 48, 'respective': 14, 'disadvantages': 13, 'homography': 1, 'planar': 8, 'feature': 286, 'points': 98, 'extracted': 58, 'images': 209, 'corresponding': 65, 'current': 342, 'desired': 44, 'poses': 22, 'computed': 38, 'iteration': 10, 'approximate': 78, 'partial': 101, 'pose': 49, 'translational': 3, 'term': 116, 'known': 174, 'scale': 159, 'factor': 32, 'deduced': 1, 'designed': 198, 'closed': 26, 'loop': 18, 'law': 23, 'controlling': 26, 'd': 131, 'o': 142, 'f': 69, 'contrarily': 2, 'position': 99, 'scheme': 165, 'need': 313, 'geometric': 31, '3d': 145, 'model': 1241, 'furthermore': 103, 'ensures': 11, 'convergence': 39, 'task': 478, 'space': 410, 'building': 225, 'datablades': 2, 'know': 58, 'value': 140, 'cost': 218, 'relational': 258, 'database': 853, 'management': 408, 'ordbms': 6, 'offers': 56, 'potential': 129, 'benefits': 54, 'scientific': 69, 'multimedia': 128, 'financial': 18, 'applications': 876, 'work': 631, 'remains': 32, 'integration': 268, 'domain': 396, 'specific': 293, 'class': 282, 'libraries': 132, 'data': 2763, 'cartridges': 2, 'extenders': 1, 'query': 1168, 'processing': 410, 'major': 130, 'problem': 1023, 'standard': 203, 'mechanisms': 130, 'selectivity': 17, 'estimation': 88, 'taken': 61, 'systems': 1830, 'rely': 38, 'properties': 207, 'types': 209, 'creation': 75, 'extremely': 36, 'difficult': 162, 'software': 574, 'interfaces': 245, 'provided': 151, 'vendors': 7, 'relatively': 62, 'low': 129, 'level': 382, 'discuss': 248, 'extensions': 64, 'generalized': 46, 'search': 1032, 'tree': 181, 'gist': 2, 'support': 580, 'higher': 90, 'type': 180, 'specifically': 77, 'computation': 105, 'estimates': 40, 'confidence': 30, 'intervals': 27, 'variety': 165, 'index': 201, 'approaches': 370, 'present': 784, 'results': 926, 'experimental': 225, 'comparison': 72, 'methods': 683, 'estimators': 9, 'literature': 98, 'intro': 2, 'impulse': 3, 'location': 169, 'agent': 1688, 'assistance': 26, 'physical': 171, 'world': 537, 'user': 1306, 'experiences': 55, 'products': 44, 'places': 32, 'explores': 26, 'surroundings': 6, 'participates': 1, 'activities': 105, 'agents': 1565, 'trapped': 2, 'electronic': 161, 'offer': 66, 'users': 578, 'valuable': 34, 'online': 107, 'example': 293, 'personalizing': 1, 'searches': 38, 'queries': 651, 'research': 693, 'project': 200, 'mit': 5, 'media': 75, 'lab': 23, 'examines': 27, 'happens': 5, 'rich': 62, 'experience': 119, 'augmented': 164, 'costs': 37, 'information': 2359, 'resources': 192, 'available': 305, 'internet': 327, 'presents': 308, 'subset': 62, 'implementation': 347, 'aspect': 46, 'scenario': 45, 'demonstrating': 17, 'mobile': 709, 'device': 94, 'uses': 223, 'aware': 85, 'digitally': 3, 'augment': 17, 'explore': 93, 'overview': 101, 'related': 223, 'learning': 1499, 'wireless': 70, 'devices': 161, '6': 124, 'combined': 107, 'wearable': 187, 'computing': 427, 'ubiquitous': 112, '5': 167, 'placing': 2, 'environment': 538, 'takes': 51, 'previous': 174, 'explorations': 6, 'introduces': 74, 'idea': 110, 'exploiting': 53, 'context': 452, 'delivered': 15, 'relevant': 205, 'tasks': 379, 'truly': 11, 'environments': 323, 'greater': 35, 'challenge': 75, 'transmitted': 6, 'requires': 133, 'shared': 107, 'understanding': 138, 'humans': 79, 'computational': 186, 'essay': 1, 'articulates': 2, 'problems': 552, 'addressed': 39, 'representing': 92, 'unique': 48, 'possibilities': 19, 'design': 779, 'represent': 181, 'domains': 188, 'guidelines': 38, 'solutions': 161, 'rationale': 9, 'larger': 40, 'embedded': 78, 'fixed': 62, 'entity': 25, 'sensed': 4, 'emerging': 68, 'unbounded': 2, 'address': 153, 'challenge ...

# %%
# Total number of words in the collection
file = open('tokens_3.txt')
data = file.read()
words = data.split()
len(words)
# Out:
# 284504

# %%
# Total number of unique words in the collection
len(count)
# Out:
# 17029

# %%
# Top 20 words and their frequencies in the collection
top20_words = dict(sorted(count.items(), key=operator.itemgetter(1),reverse=True)[:20])
print(top20_words)
# Out:
# {'data': 2763, 'based': 2534, 'information': 2359, 'paper': 2211, 'systems': 1830, '1': 1783, 'agent': 1688, 'agents': 1565, 'web': 1556, 'learning': 1499, 'user': 1306, 'model': 1241, 'approach': 1169, 'query': 1168, 'search': 1032, 'problem': 1023, 'new': 977, 'use': 959, 'introduction': 952, 'time': 930}

# %%
# Stopwords in the Top 20 words in the collection
for i in top20_words.keys():
    if i in STOPWORDS:
        print(i,'')

# %%
# Minimum number of unique words accounting for 15% of the total number of words in the collection
c = 0
no_of_words =0
count = dict(sorted(count.items(), key=operator.itemgetter(1),reverse=True))
limit = len(words)*0.15
for i in count:
    if c < limit and count[i] <= (limit - c):
        print(i,':', count[i])
        c += count[i]
        no_of_words += 1   
print('\nNumber of words:',no_of_words)
print('Total count:',c)
# Out:
# data : 2763
# based : 2534
# information : 2359
# paper : 2211
# systems : 1830
# 1 : 1783
# agent : 1688
# agents : 1565
# web : 1556
# learning : 1499
# user : 1306
# model : 1241
# approach : 1169
# query : 1168
# search : 1032
# problem : 1023
# new : 977
# use : 959
# introduction : 952
# time : 930
# results : 926
# knowledge : 915
# algorithm : 884
# applications : 876
# database : 853
# s : 817
# techniques : 798
# present : 784
# language : 782
# design : 779
# performance : 736
# mobile : 709
# algorithms : 694
# research : 693
# set : 693
# speech : 191
#
# Number of words: 36
# Total count: 42675
